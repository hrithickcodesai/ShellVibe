# %%
import os
os.chdir('/content/drive/MyDrive/AI/ShellVibe')

# %%
! ls
# Out:
# data	      Makefile	 pyproject.toml  src	      train.py
# inference.py  notebooks  README.md	 train.ipynb  uv.lock

# %%
! pip install datasets levenshtein matplotlib python-dotenv seaborn torch tqdm transformers wandb wordcloud
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.3/153.3 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 67.3 MB/s eta 0:00:00
# ...

# %%
! python3 -m src.training.train
# Out:
# Using CUDA: Tesla T4
# Using dtype: torch.bfloat16
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: hrithick-codes (personal-nlp-projects) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ setting up run ix99njqn (0.2s)
# wandb: ⣾ setting up run ix99njqn (0.2s)
# wandb: ⣷ setting up run ix99njqn (0.2s)
# wandb: ⣯ setting up run ix99njqn (0.2s)
# wandb: Tracking run with wandb version 0.25.0
# wandb: Run data is saved locally in /content/drive/MyDrive/AI/ShellVibe/wandb/run-20260316_075922-ix99njqn
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run electric-shape-6
# wandb: ⭐️ View project at https://wandb.ai/personal-nlp-projects/qwen-coder-bash-sft
# wandb: 🚀 View run at https://wandb.ai/personal-nlp-projects/qwen-coder-bash-sft/runs/ix99njqn
# Loading Qwen/Qwen2.5-Coder-0.5B...
# ...
